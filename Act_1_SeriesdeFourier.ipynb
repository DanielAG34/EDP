# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielAG34/EDP/blob/main/Act_1_SeriesdeFourier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importamos la libreria de python correspondiente

# %%
from pylab import *

# %% [markdown]
# Creamos la estructura de la función para gráficar ambas funciones

# %%
def funcion_1(x):
    y = zeros(len(x))
    for i in range(len(x)):
        y[i] = 0
    return y

# %%
def funcion_2(z):
    y = zeros(len(z))
    for i in range(len(z)):
        y[i] = 2-x[i]
    return y

# %% [markdown]
# Especificamos ambas funciones/ función a trozos para que gráfique las funciones con las condiciones correspondientes

# %%
x_1 = linspace(-2,0,1000)
x_2 = linspace(0,2,1000)
f = funcion_1(x)
g = funcion_2(x)
plot(x,f,label='$u_{2}(-2,0)=0$')
plot(z,g,label='$u_{1}(0,2)=2-x$')
plt.xlabel('$x$'); plt.ylabel('$f(x)$');
plt.title("Condiciones iniciales f(x)y g(x))")
xlim([-4,5]),ylim([-1,6]),grid(),legend()
show()

# %% [markdown]
# Construimos la estructura para la gráfica de la serie de Fourier,para ambas funciones con un número de armonicos igual a 10

# %%
def u_1(z,N=10):
    g= zeros(len(z))
    for n in range(1,N):
        g += (-1)**(n+1)*sin(n*pi*x)/(n)
    return (2.0/pi)*g

# %%
def u_0(x,N=10):
    f= zeros(len(x))
    for n in range(1,N):
        f += (-1)**(n+1)*sin(n*pi*x)/(n)
    return (2.0/pi)*f

# %% [markdown]
# Especificamos los datos de la gráfica para finalmente ejecutar el código

# %%
x_1 = linspace(-2,0,1000)
x_2 = linspace(0,2,1000)
f_n = u_0(x)
g_n = u_1(z)
plot(x,f_n,label='$f_N(x)$ con $N=10$')
plot(x,f,label='$f(x)=0$')
plot(z,g_n,label='$g_N(x)$ con $N=10$')
plot(z,g,label='$g(x)=2-x$')
plt.xlabel('$x$'); plt.ylabel('$f(x)$');
plt.title("Aproximación de las condiciones iniciales")
xlim([-4,5]),ylim([-1,6]),grid(),legend()
show()
